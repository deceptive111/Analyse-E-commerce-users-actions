# %%
import pandas as pd
import numpy as np

# %%
original_data=pd.read_csv("ecommerce_user_behavior_dataset.csv",encoding="gbk")
original_data.head()
# Out:
#                User_ID                  Age               Gender  \
# 0  每个用户的唯一标识符，便于追踪和分析。  用户的年龄，提供对人口统计偏好的洞察。  用户的性别，使能性别特定的推荐和定位。
# 1                   #1                   56                 Male
# 2                   #2                   46               Female
# 3                   #3                   32               Female
# 4                   #4                   60               Female
#
#                      Location               Income  \
# 0  用户所在地区：郊区、农村、城市，影响偏好和购物习惯。  用户的收入水平，表明购买力和支付能力。
# 1                    Suburban                38037
# 2                       Rural               103986
# 3                    Suburban               101942
# 4                    Suburban                71612
#
#                      Interests  Last_Login_Days_Ago     Purchase_Frequency  \
# 0  用户的兴趣，如运动、时尚、技术等，指导内容和产品推荐。  用户上次登录以来的天数，反映参与频率。  用户进行购买的频率，表明购物习惯和忠诚度。
# 1                       Sports                    5                      7
# ...
